# %%
import pandas as pd


# employees = {
#     "Employee_ID": [101, 102, 103, 104, 105, 106, 107, 108],
#     "Name": ["Rahul", "Priya", "Amit", "Sneha", "Karan", "Pooja", "Rohan", "Neha"],
#     "Department": ["Sales", "HR", "IT", "Sales", "IT", "Finance", "HR", "Sales"],
#     "Age": [25, 30, 28, 35, 26, 40, 29, 31],
#     "Salary": [40000, 50000, 70000, 55000, 72000, 90000, 52000, 58000]
# }

# df = pd.DataFrame(employees)
# df


# Display the first 5 rows.

# df.head(5)

# read csv

# df = pd.read_csv("challan.csv")
# df

# Display the first 5 rows

# df.head(3)



# last_rows 

# df.tail()


# See number of rows and columns

# df.shape

# Column names

# df.columns



# data types

# df.dtypes


# Summary

# df.info()


# Selecting Columns

# df.head() === Shows the first 5 rows (helps inspect the data and column names)

# df["ch_challan_no"] ------------------- fetch this ch_challan_no column and its data


# Multiple columns

# df[["ch_challan_no", "ch_net_amt"]] --------------------- 2 columns with data alwasy use a bracket 1 bracket for 1 column


# df.loc[0:3] ----------------------------------- slicing type allows us to fetch the rows as per index start with 0 (If your index labels are 0,1,2,3..., it looks like slicing, but loc actually uses labels.)



# df.loc[:,["ch_challan_no","ch_net_amt"]]  ----------------------------------- specific columns with all rows data


# df.loc[2,"ch_challan_no"] ---------------- finds the 2nd rows value by mentioning a column name 


# Position based.
# df.iloc[0]  --------------------- as per indexing its will fetch the first row

# df.iloc[0:3] ---------------------------- fetch first 3 rows ( as per indexing starts with 0)

# df.iloc[2,4] --------------------- finds a specific value ( rows number , values) (# Fetches the value at row position 2 and column position 4)

# loc	iloc
# Label	Position
# End included	End excluded
# Column names	Column numbers


# Filtering

# ch_net_amt >50000

# df[df["ch_net_amt"]>50000] -------------------- works like a where clause value 

# df = pd.read_csv("dat.csv")
# df

# df.head()

# df[df["job"]=="Marketing Manager"] ----------------- filter only for job = 'Marketing Manager'

# df[df["hourly_pay"]>2000] --------------------------- filters like hourly_pay > 2000

# df[
#     (df["job"]=="Marketing Manager")
#     & ------------- and 
#     (df["Salary"]>60000)
# ]      ---------------------------------------------------- multiple with and  conditions 

# df
# df[
#     (df["job"]=="Marketing Manager")
#     | --------------------------------- or multiple with or  conditions
#     (df["job"]=="Accountant Executive")
# ]


# df[
#     df["job"]!="Marketing Manager"    -------------------------- not
# ]


# df[
    # df["job"].isin(["Accountant Executive","Chief Executive Officer","Ux/Ui Designer"])   ------------- in clause 
# ]




# sorting 

# asc order
# df.sort_values("Salary")

# desc order
# df.sort_values(
#     "Salary",
#     ascending=False
# )




# df.sort_values("hourly_pay") ------------------- asc order sort by hourly_pay


# df.sort_values(

    # ["job","Salary"] ------------------------- both asc orders
# )

# df.sort_values(
#     by=["job", "Salary"], 
#     ascending=[True, False]  -------------------- true asc , false = desc
# )






# df["Salary"] ------------------- no heading only values in this columns

# df[["Salary"]] --------------------------------- heading with column values


# Write the code to display only these three columns:

# first_name
# job
# hourly_pay

df = pd.read_csv("dat.csv")

# df[["First_Name", "job", "hourly_pay"]]


# Display only the employees whose:

# job is "Marketing Manager"

# df[df["job"]=="Marketing Manager"]



# Display employees who satisfy both conditions:

# job is "Marketing Manager"
# hourly_pay is greater than 2000


# df[
#     (df["job"]=="Marketing Manager")
#     &
#     (df["hourly_pay"]> 2000)
# ]


# Display all employees whose job is either:

# "Marketing Manager"
# OR
# "Accountant Executive"

# Show all columns.


df[
    (df["job"]=="Marketing Manager")
    |
    (df["job"] == "Accountant Executive")
]
df[df["job"].isin(["Marketing Manager", "Accountant Executive"])]
# Out:
#     emp_id First_Name  Last_Name  hourly_pay  Salary                   job  \
# 0        1    Aaliyah     Solace        2085  761025  Accountant Executive
# 1        2    Abigail     Levine        2146  783290     Marketing Manager
# 4        5      Alice     Bardot        1897  692405  Accountant Executive
# 7        8       Aria   Cromwell        1888  689120     Marketing Manager
# 11      12     Audrey    Langley        2040  744600  Accountant Executive
# 13      14     Autumn    Madison        2051  748615  Accountant Executive
# 15      16      Avery      Ellis        1905  695325     Marketing Manager
# 18      19   Brooklyn      Lopez        1917  699705  Accountant Executive
# 22      23     Claire   Gonzales        1700  620500  Accountant Executive
# 23      24       Cora     Keller        2124  775260  Accountant Executive
# 29      30       Ella     Ledger        1683  614295     Marketing Manager
# ...
