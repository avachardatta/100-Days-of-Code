# %%
import pandas as pd

students = {
    "Student_ID": [201, 202, 203, 204, 205, 206, 207, 208, 209, 210],
    "Name": [
        "Arjun", "Meera", "Kabir", "Ananya", "Rohit",
        "Isha", "Vikram", "Sara", "Yash", "Diya"
    ],
    "Course": [
        "Python", "SQL", "Python", "Power BI", "Excel",
        "SQL", "Python", "Excel", "Power BI", "SQL"
    ],
    "Age": [22, 24, 23, 25, 21, 26, 24, 22, 23, 25],
    "Marks": [85, 92, 78, 88, 74, 95, 81, 69, 90, 84],
    "City": [
        "Pune", "Mumbai", "Delhi", "Pune", "Nagpur",
        "Mumbai", "Delhi", "Pune", "Hyderabad", "Mumbai"
    ]
}

df = pd.DataFrame(students)

# df.head(7) ----------------- First 7 rows
# df.tail(4) ----------------------- last 4 rows

# Display the number of rows and columns in the DataFrame.

# df.shape


# Display only the column names of the DataFrame.

# df.columns



# Display the data type of each column.

# df.dtypes



# Display a summary of the DataFrame, including:

# Number of rows
# Number of columns
# Data types
# Non-null values


# df.info()


# Display only the Name column.

# df['Name']


# Display only these three columns:

# df[['Name','Course','Marks']]


# Display the first 5 rows using loc


# df.loc[0:4]

# Using loc, display:

# All rows
# Only these columns:
# Name
# Marks


# df.loc[:,['Name','Marks']]


# Using loc, display the Marks of the student at index 6.

# df.loc[6,'Marks']


# Using iloc, display the first 5 rows of the DataFrame.


# df.iloc[0:5]



# Using iloc, display:

# All rows
# The 2nd, 3rd, and 4th columns (by position)


# df.iloc[:, 1:4]


# Using iloc, display the value at:

# row position 4
# column position 2



# df.iloc[4,2]



# Using this dataset, display only the students whose:

# Course is "Python"

# df[df['Course']=='Python']




# Display only the students whose:

# Marks are greater than 85


# df[df['Marks']>=85]



# Display students who satisfy both conditions:

# Course is "SQL"
# Marks are greater than 90


# df[
#     (df['Course'] == 'SQL')
#     &
#     (df['Marks'] >90)
# ]


# df[(df['Course'] == 'SQL') & (df['Marks'] > 90)]



# Display students who satisfy either of these conditions:

# Course is "Python"
# OR
# City is "Mumbai"




# df[
#     (df['Course'] == 'Python')
#     |
#     (df['City'] == 'Mumbai')
# ]


# Display students whose Course is any one of these:

# "Python"
# "SQL"
# "Excel"


# df.head()

# df[df['Course'].isin(['Python','SQL','Excel'])]



# Display all students except those whose Course is "Python".

# df[df['Course']!= 'Python']




# Using the same dataset, write code to:

# Show only the columns:
# Name
# Course
# Marks
# Include only students whose:
# Course is either "Python" or "SQL"
# AND
# Marks are greater than 80


df.loc[
    (df['Course'].isin(['Python','SQL']))
    &
    (df['Marks']> 80), ['Name','Course','Marks']

]


# df.loc[(df['Course'].isin(['Python', 'SQL'])) & (df['Marks'] > 80), ['Name', 'Course', 'Marks']]


# df[
#     (df['Course'] == 'Python')
#     |
#     (df['City'] == 'Mumbai')
# ]
# Out:
#      Name  Course  Marks
# 0   Arjun  Python     85
# 1   Meera     SQL     92
# 5    Isha     SQL     95
# 6  Vikram  Python     81
# 9    Diya     SQL     84
